# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in e:\anaconda\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in e:\anaconda\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\anaconda\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in e:\anaconda\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in e:\anaconda\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in e:\anaconda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in e:\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in e:\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\anaconda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\anaconda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
# Load the dataset
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data.head()
# Out:
#         Date  New COVID-19 Cases  Total Death COVID-19 Cases  \
# 0 2021-01-04                1704                         494
# 1 2021-01-05                1741                         501
# 2 2021-01-06                2027                         509
# 3 2021-01-07                2593                         513
# 4 2021-01-08                3027                         521
#
#    New deaths COVID-19 Cases  Recoveries COVID-19 Cases  Day Average Temp  \
# 0                         11                       1010              26.4
# 1                          7                       1221              26.5
# 2                          8                       1129              27.7
# 3                          4                       2145              26.9
# 4                          8                       2708              27.5
#
#    Rainfall (mm)  Vaccination Rate  Population Density  \
# 0           11.5                 0              96.254
# 1            1.0                 0              96.254
# 2            0.0                 0              96.254
# 3           25.8                 0              96.254
# 4            0.0                 0              96.254
#
#    Total Infected COVID-19 Cases
# 0                       3508.641
# 1                       3559.940
# 2                       3619.666
# 3                       3696.069
# 4                       3785.261

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['Recoveries COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0, 3, 2))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     Recoveries COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 3, 2)   Log Likelihood               -1730.439
# Date:                       Mon, 28 Jul 2025   AIC                           3466.877
# Time:                               10:44:20   BIC                           3477.003
# Sample:                           01-04-2021   HQIC                          3470.968
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.9903      0.073    -27.110      0.000      -2.134      -1.846
# ma.L2          0.9903      0.073     13.611      0.000       0.848       1.133
# sigma2      4.978e+05   2.91e-07   1.71e+12      0.000    4.98e+05    4.98e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  18.21   Jarque-Bera (JB):                23.37
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.20   Skew:                             0.03
# Prob(H) (two-sided):                  0.44   Kurtosis:                         4.61
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.16e+27. Standard errors may be unstable.
# Mean Squared Error (MSE): 6669508.99
# Mean Absolute Error (MAE): 1831.91
# Mean Absolute Percentage Error (MAPE): 9.37%
# Root Mean Squared Error (RMSE): 2582.54
# Relative RMSE (RRMSE): 0.3079
# Normalized RMSE (NRMSE): 0.1287
# R-squared (R²): -0.3270

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,3,2))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 3, 2)   Log Likelihood               -1014.622
# Date:                       Mon, 28 Jul 2025   AIC                           2035.245
# Time:                               16:46:11   BIC                           2045.370
# Sample:                           01-04-2021   HQIC                          2039.336
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.9974      0.573     -3.486      0.000      -3.121      -0.874
# ma.L2          0.9996      0.574      1.743      0.081      -0.125       2.124
# sigma2       655.7692    377.469      1.737      0.082     -84.057    1395.595
# ===================================================================================
# Ljung-Box (L1) (Q):                  48.14   Jarque-Bera (JB):              1707.10
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              68.01   Skew:                             0.18
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.77
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 3606.44
# Mean Absolute Error (MAE): 43.60
# Mean Absolute Percentage Error (MAPE): 14.39%
# Root Mean Squared Error (RMSE): 60.05
# Relative RMSE (RRMSE): 0.1437
# Normalized RMSE (NRMSE): 0.1988
# R-squared (R²): 0.4591

# %%
# Assuming your model is called `arima_model`
forecast = arima_model.forecast(steps=7)  # 7 days forecast
forecast.index = pd.date_range(start='2021-09-12', periods=7, freq='D')
print(forecast)
# Out:
# 2021-09-12    214.861057
# 2021-09-13    217.821250
# 2021-09-14    220.880577
# 2021-09-15    224.039040
# 2021-09-16    227.296638
# 2021-09-17    230.653372
# 2021-09-18    234.109241
# Freq: D, Name: predicted_mean, dtype: float64

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,2,5))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 2, 5)   Log Likelihood                -940.107
# Date:                       Mon, 28 Jul 2025   AIC                           1892.213
# Time:                               10:52:28   BIC                           1912.493
# Sample:                           01-04-2021   HQIC                          1900.405
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.9550      0.049    -39.909      0.000      -2.051      -1.859
# ma.L2          0.9831      0.109      9.023      0.000       0.770       1.197
# ma.L3          0.1832      0.129      1.416      0.157      -0.070       0.437
# ma.L4         -0.1004      0.130     -0.772      0.440      -0.355       0.155
# ma.L5         -0.0949      0.064     -1.494      0.135      -0.219       0.030
# sigma2       329.3486     13.716     24.013      0.000     302.466     356.231
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.09   Jarque-Bera (JB):              2779.31
# Prob(Q):                              0.76   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.60   Skew:                             2.29
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.93
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 6849.24
# Mean Absolute Error (MAE): 70.21
# Mean Absolute Percentage Error (MAPE): 25.95%
# Root Mean Squared Error (RMSE): 82.76
# Relative RMSE (RRMSE): 0.1980
# Normalized RMSE (NRMSE): 0.2739
# R-squared (R²): -0.0272

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,2,4))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 2, 4)   Log Likelihood                -940.771
# Date:                       Mon, 28 Jul 2025   AIC                           1891.543
# Time:                               10:55:59   BIC                           1908.442
# Sample:                           01-04-2021   HQIC                          1898.370
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.9816      0.055    -36.134      0.000      -2.089      -1.874
# ma.L2          0.9943      0.126      7.922      0.000       0.748       1.240
# ma.L3          0.2957      0.119      2.480      0.013       0.062       0.529
# ma.L4         -0.2908      0.046     -6.392      0.000      -0.380      -0.202
# sigma2       331.3461     12.234     27.084      0.000     307.368     355.324
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              3022.49
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):              32.49   Skew:                             2.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 7544.57
# Mean Absolute Error (MAE): 74.32
# Mean Absolute Percentage Error (MAPE): 27.30%
# Root Mean Squared Error (RMSE): 86.86
# Relative RMSE (RRMSE): 0.2078
# Normalized RMSE (NRMSE): 0.2875
# R-squared (R²): -0.1315

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,1,5))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 1, 5)   Log Likelihood                -945.728
# Date:                       Mon, 28 Jul 2025   AIC                           1903.457
# Time:                               10:58:34   BIC                           1923.764
# Sample:                           01-04-2021   HQIC                          1911.659
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9233      0.052    -17.728      0.000      -1.025      -0.821
# ma.L2          0.0172      0.066      0.260      0.795      -0.112       0.147
# ma.L3          0.1741      0.071      2.446      0.014       0.035       0.314
# ma.L4          0.1330      0.064      2.064      0.039       0.007       0.259
# ma.L5          0.0417      0.055      0.763      0.445      -0.065       0.149
# sigma2       340.3027     16.276     20.909      0.000     308.403     372.202
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.16   Jarque-Bera (JB):              3214.22
# Prob(Q):                              0.69   Prob(JB):                         0.00
# Heteroskedasticity (H):              35.43   Skew:                             2.72
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.01
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 7760.21
# Mean Absolute Error (MAE): 62.11
# Mean Absolute Percentage Error (MAPE): 18.92%
# Root Mean Squared Error (RMSE): 88.09
# Relative RMSE (RRMSE): 0.2107
# Normalized RMSE (NRMSE): 0.2916
# R-squared (R²): -0.1638

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,1,4))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 1, 4)   Log Likelihood                -945.845
# Date:                       Mon, 28 Jul 2025   AIC                           1901.690
# Time:                               11:01:47   BIC                           1918.613
# Sample:                           01-04-2021   HQIC                          1908.525
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9275      0.046    -20.162      0.000      -1.018      -0.837
# ma.L2          0.0033      0.064      0.052      0.959      -0.123       0.129
# ma.L3          0.1865      0.067      2.778      0.005       0.055       0.318
# ma.L4          0.1615      0.053      3.048      0.002       0.058       0.265
# sigma2       340.7306     16.038     21.245      0.000     309.296     372.165
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):              2878.80
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):              34.94   Skew:                             2.61
# Prob(H) (two-sided):                  0.00   Kurtosis:                        20.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 8006.01
# Mean Absolute Error (MAE): 63.20
# Mean Absolute Percentage Error (MAPE): 19.08%
# Root Mean Squared Error (RMSE): 89.48
# Relative RMSE (RRMSE): 0.2141
# Normalized RMSE (NRMSE): 0.2962
# R-squared (R²): -0.2007

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New deaths COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,1,3))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                    SARIMAX Results
# =====================================================================================
# Dep. Variable:     New deaths COVID-19 Cases   No. Observations:                  219
# Model:                        ARIMA(0, 1, 3)   Log Likelihood                -948.104
# Date:                       Mon, 28 Jul 2025   AIC                           1904.207
# Time:                               11:03:45   BIC                           1917.745
# Sample:                           01-04-2021   HQIC                          1909.676
#                                 - 08-10-2021
# Covariance Type:                         opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.9677      0.054    -17.771      0.000      -1.074      -0.861
# ma.L2         -0.0215      0.079     -0.274      0.784      -0.175       0.132
# ma.L3          0.3669      0.048      7.710      0.000       0.274       0.460
# sigma2       347.9850     13.539     25.703      0.000     321.450     374.520
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.05   Jarque-Bera (JB):              3304.72
# Prob(Q):                              0.82   Prob(JB):                         0.00
# Heteroskedasticity (H):              33.58   Skew:                             2.83
# Prob(H) (two-sided):                  0.00   Kurtosis:                        21.22
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 8612.77
# Mean Absolute Error (MAE): 66.21
# Mean Absolute Percentage Error (MAPE): 19.75%
# Root Mean Squared Error (RMSE): 92.81
# Relative RMSE (RRMSE): 0.2220
# Normalized RMSE (NRMSE): 0.3072
# R-squared (R²): -0.2917

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# === Load and preprocess data ===
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

target_col = 'New deaths COVID-19 Cases'
target_series = data[[target_col, 'Date']].copy()

# === Define date-based splits (same as ARIMA) ===
train_data = target_series[(target_series['Date'] <= '2021-08-10')]
test_data = target_series[(target_series['Date'] >= '2021-08-11') & (target_series['Date'] <= '2021-09-18')]

# === Normalize based on training only ===
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[[target_col]])
test_scaled = scaler.transform(test_data[[target_col]])

# === Create sequences ===
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len:i])
        y.append(data[i])
    return np.array(X), np.array(y)

seq_length = 10
x_train, y_train = create_sequences(train_scaled, seq_length)
x_test, y_test = create_sequences(test_scaled, seq_length)

# === Build and train LSTM model ===
model = Sequential()
model.add(LSTM(64, input_shape=(seq_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, epochs=200, batch_size=16, verbose=1)

# === Predict on test set ===
y_pred = model.predict(x_test)

# === Inverse scale predictions and true values ===
y_pred_rescaled = scaler.inverse_transform(y_pred)
y_test_rescaled = scaler.inverse_transform(y_test)

# === Evaluate LSTM model ===
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = np.mean(np.abs((y_test_rescaled - y_pred_rescaled) / y_test_rescaled)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(y_test_rescaled) - np.min(y_test_rescaled))
nrmse = rmse / np.mean(y_test_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

print("\n📊 Final LSTM Forecast Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Epoch 1/200
# E:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0326
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0080
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0023
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0043
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0047
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0031
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0028
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0029
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0024
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0040
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0034
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0041
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0030
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0026
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0037
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0050
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0034
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0039
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0029
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0027
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0026
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0030
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0025
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0037
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0035
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 187/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 188/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025
# Epoch 189/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 190/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 191/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025
# Epoch 192/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 193/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 194/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039
# Epoch 195/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 196/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
#
# 📊 Final LSTM Forecast Evaluation:
# Mean Squared Error (MSE): 38054.37
# Mean Absolute Error (MAE): 160.93
# Mean Absolute Percentage Error (MAPE): 54.68%
# Root Mean Squared Error (RMSE): 195.08
# Relative RMSE (RRMSE): 0.4667
# Normalized RMSE (NRMSE): 0.6107
# R-squared (R²): -4.3171

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# === Load and preprocess data ===
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

target_col = 'New deaths COVID-19 Cases'
target_series = data[[target_col, 'Date']].copy()

# === Define date-based splits (same as ARIMA) ===
train_data = target_series[(target_series['Date'] <= '2021-08-10')]
test_data = target_series[(target_series['Date'] >= '2021-08-11') & (target_series['Date'] <= '2021-09-18')]

# === Normalize based on training only ===
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[[target_col]])
test_scaled = scaler.transform(test_data[[target_col]])

# === Create sequences ===
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len:i])
        y.append(data[i])
    return np.array(X), np.array(y)

seq_length = 10
x_train, y_train = create_sequences(train_scaled, seq_length)
x_test, y_test = create_sequences(test_scaled, seq_length)

# === Build and train LSTM model ===
model = Sequential()
model.add(LSTM(64, input_shape=(seq_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, epochs=200, batch_size=16, verbose=1)

# === Predict on test set ===
y_pred = model.predict(x_test)

# === Inverse scale predictions and true values ===
y_pred_rescaled = scaler.inverse_transform(y_pred)
y_test_rescaled = scaler.inverse_transform(y_test)

# === Evaluate LSTM model ===
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = np.mean(np.abs((y_test_rescaled - y_pred_rescaled) / y_test_rescaled)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(y_test_rescaled) - np.min(y_test_rescaled))
nrmse = rmse / np.mean(y_test_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

print("\n📊 Final LSTM Forecast Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Epoch 1/200
# E:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.0230
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0022
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0027
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0028
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0022
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0024
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0031
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0025
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0026
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0034
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0031
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0032
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0031
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0038
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0026
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0024
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0023
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0028
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0035
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0038
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0033
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0024
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0025
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0053
# Epoch 187/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 188/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 189/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0029
# Epoch 190/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0032
# Epoch 191/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 192/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 193/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0038
# Epoch 194/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0024
# Epoch 195/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0025
# Epoch 196/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
#
# 📊 Final LSTM Forecast Evaluation:
# Mean Squared Error (MSE): 13558.35
# Mean Absolute Error (MAE): 94.10
# Mean Absolute Percentage Error (MAPE): 31.26%
# Root Mean Squared Error (RMSE): 116.44
# Relative RMSE (RRMSE): 0.2786
# Normalized RMSE (NRMSE): 0.3645
# R-squared (R²): -0.8944

# %%
# === Define forecast horizon (same as your ARIMA example) ===
forecast_horizon = pd.date_range(start='2021-09-12', end='2021-09-18')

# === Start with the last known sequence from test data ===
last_sequence = test_scaled[-seq_length:]  # shape (10, 1)

forecast_scaled = []

for _ in range(len(forecast_horizon)):
    # Reshape to (1, seq_len, 1) for LSTM input
    input_seq = last_sequence.reshape((1, seq_length, 1))

    # Predict next value
    next_scaled = model.predict(input_seq, verbose=0)[0][0]

    # Append prediction
    forecast_scaled.append([next_scaled])

    # Update sequence: drop first, append prediction
    last_sequence = np.vstack((last_sequence[1:], [[next_scaled]]))

# Inverse transform forecasted values
forecast_scaled = np.array(forecast_scaled)
forecast_rescaled = scaler.inverse_transform(forecast_scaled)

# Convert to Pandas Series with date index
lstm_forecast_series = pd.Series(forecast_rescaled.flatten(), index=forecast_horizon)

print("\n📈 LSTM Rolling Forecast:")
print(lstm_forecast_series)
# Out:
# 📈 LSTM Rolling Forecast:
# 2021-09-12    675.270996
# 2021-09-13    622.351379
# 2021-09-14    533.940491
# 2021-09-15    499.129272
# 2021-09-16    658.874390
# 2021-09-17    756.983398
# 2021-09-18    876.391479
# Freq: D, dtype: float32

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# === Step 1: Load and prepare data ===
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

target_col = 'New deaths COVID-19 Cases'
ts = data.set_index('Date')[target_col]

# === Step 2: Train/test split ===
train_ts = ts[:'2021-08-10']
test_ts = ts['2021-08-11':'2021-09-18']

# === Step 3: Fit best ARIMA model ===
best_order = (0, 3, 2)  # Use your best found (p,d,q) here
arima_model = ARIMA(train_ts, order=best_order).fit()

# === Step 4: Forecast on test set using ARIMA ===
arima_forecast = arima_model.forecast(steps=len(test_ts))
arima_forecast.index = test_ts.index

# === Step 5: Calculate residuals on training data ===
arima_pred_train = arima_model.predict(start=train_ts.index[1], end=train_ts.index[-1])
residuals = train_ts[1:] - arima_pred_train

# === Step 6: Scale residuals and create LSTM sequences ===
scaler = MinMaxScaler()
residuals_scaled = scaler.fit_transform(residuals.values.reshape(-1, 1))

def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len:i])
        y.append(data[i])
    return np.array(X), np.array(y)

seq_len = 10
x_lstm, y_lstm = create_sequences(residuals_scaled, seq_len)

# === Step 7: Build and train LSTM ===
model = Sequential()
model.add(LSTM(64, input_shape=(seq_len, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_lstm, y_lstm, epochs=200, batch_size=16, verbose=1)

# === Step 8: Predict residuals on test set ===
resid_history = residuals_scaled[-seq_len:].flatten().tolist()
lstm_pred_scaled = []

for _ in range(len(test_ts)):
    input_seq = np.array(resid_history[-seq_len:]).reshape(1, seq_len, 1)
    pred = model.predict(input_seq, verbose=0)[0][0]
    lstm_pred_scaled.append(pred)
    resid_history.append(pred)

lstm_pred_resid = scaler.inverse_transform(np.array(lstm_pred_scaled).reshape(-1, 1)).flatten()

# === Step 9: Final hybrid forecast ===
hybrid_forecast = arima_forecast.values + lstm_pred_resid

# === Step 10: Evaluate hybrid model ===
actual = test_ts.values
mse = mean_squared_error(actual, hybrid_forecast)
mae = mean_absolute_error(actual, hybrid_forecast)
mape = np.mean(np.abs((actual - hybrid_forecast) / actual)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(actual) - np.min(actual))
nrmse = rmse / np.mean(actual)
r2 = r2_score(actual, hybrid_forecast)

print("\n📊 Final Hybrid ARIMA + LSTM Forecast Evaluation:")
print(f"ARIMA Order Used: {best_order}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")

# === Plot actual vs hybrid forecast ===
plt.figure(figsize=(10, 5))
plt.plot(test_ts.index, actual, label='Actual', marker='o')
plt.plot(test_ts.index, hybrid_forecast, label='Hybrid Forecast', marker='x')
plt.title(f"Hybrid ARIMA + LSTM Forecast\nR² = {r2:.4f}")
plt.xlabel("Date")
plt.ylabel("COVID-19 Cases")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.1897
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0080
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0088
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0070
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0071
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0083
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0102
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0052
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0114
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0102
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0063
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0062
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0099
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0075
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0092
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0110
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0082
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0091
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0078
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0078
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0090
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0066
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0100
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0056
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0086
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0090
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0089
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0084
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0079
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0074
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0078
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0084
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0069
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0080
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0075
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0101
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0058
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0069
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0058
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0049
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0070
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0091
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0067
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0069
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0076
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0060
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0080
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0056
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0031
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0043
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0042
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0112
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0054
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0084
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0042
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0089
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0042
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0036
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0064
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0062
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0060
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0051
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0069
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0039
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0055
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0056
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0065
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0059
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0033
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0033
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0048
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0029
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0038
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0058
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0043
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0053
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0071
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0035
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0030
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0037
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0056
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0052
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0050
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0039
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0035
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0041
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0026
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0040
#
# 📊 Final Hybrid ARIMA + LSTM Forecast Evaluation:
# ARIMA Order Used: (0, 3, 2)
# Mean Squared Error (MSE): 3510.49
# Mean Absolute Error (MAE): 45.06
# Mean Absolute Percentage Error (MAPE): 15.28%
# Root Mean Squared Error (RMSE): 59.25
# Relative RMSE (RRMSE): 0.1417
# Normalized RMSE (NRMSE): 0.1961
# R-squared (R²): 0.4735

# %%
# === Extract hybrid forecast for 12/9/21 to 18/9/21 ===
forecast_range = pd.date_range(start='2021-09-12', end='2021-09-18')
hybrid_forecast_series = pd.Series(hybrid_forecast, index=test_ts.index)
selected_forecast = hybrid_forecast_series.loc[forecast_range]

# Print forecasted values for the selected range
print("\n📅 Hybrid Forecast: 12/09/2021 to 18/09/2021")
print(selected_forecast.round(0).astype(int))
# Out:
# 📅 Hybrid Forecast: 12/09/2021 to 18/09/2021
# 2021-09-12    367
# 2021-09-13    372
# 2021-09-14    378
# 2021-09-15    385
# 2021-09-16    391
# 2021-09-17    397
# 2021-09-18    404
# dtype: int32

# %%
import matplotlib.pyplot as plt

# Dates
dates = ['12/09', '13/09', '14/09', '15/09', '16/09', '17/09', '18/09']

# Actual and forecast values
actual = [592, 292, 413, 463, 422, 346, 388]
arima = [214.86, 217.82, 220.88, 224.04, 227.30, 230.65, 234.11]
lstm = [675.27, 622.35, 533.94, 499.13, 658.87, 756.98, 876.39]
hybrid = [367, 372, 378, 385, 391, 397, 404]

# Plotting
plt.figure(figsize=(12, 8))

plt.plot(dates, actual, marker='o', label='Actual', color='black', linewidth=2)
plt.plot(dates, arima, marker='s', label='ARIMA Forecast', color='blue', linestyle='--')
plt.plot(dates, lstm, marker='^', label='LSTM Forecast', color='red', linestyle='--')
plt.plot(dates, hybrid, marker='D', label='Hybrid Forecast', color='green', linestyle='--')

# Labels and title
plt.xlabel('Date', fontsize=12)
plt.ylabel(' Number of Death Cases', fontsize=12)
plt.title('Death cases: Actual vs ARIMA, LSTM, Hybrid (12–18 Sep 2021)', fontsize=14)

# Legend and grid
plt.legend()
plt.grid(True, linestyle='--', alpha=0.99)
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Dates
dates = ['12/09', '13/09', '14/09', '15/09', '16/09', '17/09', '18/09']

# Actual and forecast values
actual = [592, 292, 413, 463, 422, 346, 388]
arima = [214.86, 217.82, 220.88, 224.04, 227.30, 230.65, 234.11]
lstm = [675.27, 622.35, 533.94, 499.13, 658.87, 756.98, 876.39]
hybrid = [367, 372, 378, 385, 391, 397, 404]

# Plotting
plt.figure(figsize=(14, 8))  # Bigger figure size

plt.plot(dates, actual, marker='o', label='Actual', color='black', linewidth=2)
plt.plot(dates, arima, marker='s', label='ARIMA Forecast', color='blue', linestyle='--')
plt.plot(dates, lstm, marker='^', label='LSTM Forecast', color='red', linestyle='--')
plt.plot(dates, hybrid, marker='D', label='Hybrid Forecast', color='green', linestyle='--')

# Labels and title with larger fonts
plt.xlabel('Date', fontsize=16)
plt.ylabel('Number of Death Cases', fontsize=16)
plt.title('Death cases: Actual vs ARIMA, LSTM, Hybrid (12–18 Sep 2021)', fontsize=18)

# Ticks font size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Legend with larger font
plt.legend(fontsize=14)

# Grid and layout
plt.grid(True, linestyle='--', alpha=0.9)
plt.tight_layout()

# Show the plot
plt.show()
