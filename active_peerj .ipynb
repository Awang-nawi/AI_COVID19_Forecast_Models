# %%
pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in e:\anaconda\lib\site-packages (0.14.2)
# Requirement already satisfied: numpy>=1.22.3 in e:\anaconda\lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in e:\anaconda\lib\site-packages (from statsmodels) (1.13.1)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in e:\anaconda\lib\site-packages (from statsmodels) (2.2.2)
# Requirement already satisfied: patsy>=0.5.6 in e:\anaconda\lib\site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in e:\anaconda\lib\site-packages (from statsmodels) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: six in e:\anaconda\lib\site-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in e:\anaconda\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\anaconda\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in e:\anaconda\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in e:\anaconda\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\anaconda\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in e:\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in e:\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in e:\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in e:\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\anaconda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in e:\anaconda\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in e:\anaconda\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in e:\anaconda\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in e:\anaconda\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
# Load the dataset
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data.head()
# Out:
#         Date  New COVID-19 Cases  Total Death COVID-19 Cases  \
# 0 2021-01-04                1704                         494
# 1 2021-01-05                1741                         501
# 2 2021-01-06                2027                         509
# 3 2021-01-07                2593                         513
# 4 2021-01-08                3027                         521
#
#    New deaths COVID-19 Cases  Recoveries COVID-19 Cases  Day Average Temp  \
# 0                         11                       1010              26.4
# 1                          7                       1221              26.5
# 2                          8                       1129              27.7
# 3                          4                       2145              26.9
# 4                          8                       2708              27.5
#
#    Rainfall (mm)  Vaccination Rate  Population Density  \
# 0           11.5                 0              96.254
# 1            1.0                 0              96.254
# 2            0.0                 0              96.254
# 3           25.8                 0              96.254
# 4            0.0                 0              96.254
#
#    Total Infected COVID-19 Cases
# 0                       3508.641
# 1                       3559.940
# 2                       3619.666
# 3                       3696.069
# 4                       3785.261

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(7,4,6))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(7, 4, 6)   Log Likelihood               -1732.275
# Date:                Mon, 28 Jul 2025   AIC                           3492.551
# Time:                        13:00:54   BIC                           3539.740
# Sample:                    01-04-2021   HQIC                          3511.617
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.8824      0.341     -5.524      0.000      -2.550      -1.214
# ar.L2         -1.0699      0.734     -1.458      0.145      -2.508       0.368
# ar.L3         -0.6145      0.566     -1.086      0.277      -1.723       0.495
# ar.L4         -0.9650      0.350     -2.756      0.006      -1.651      -0.279
# ar.L5         -0.9578      0.415     -2.308      0.021      -1.771      -0.144
# ar.L6         -0.6687      0.354     -1.889      0.059      -1.362       0.025
# ar.L7         -0.2149      0.140     -1.534      0.125      -0.489       0.060
# ma.L1         -1.2094      0.312     -3.874      0.000      -1.821      -0.598
# ma.L2         -1.5335      0.335     -4.574      0.000      -2.191      -0.876
# ma.L3          2.1958      0.594      3.696      0.000       1.032       3.360
# ma.L4          0.3961      0.562      0.705      0.481      -0.705       1.497
# ma.L5         -1.1652      0.346     -3.364      0.001      -1.844      -0.486
# ma.L6          0.3167      0.290      1.090      0.276      -0.253       0.886
# sigma2      8.159e+05   6.98e-07   1.17e+12      0.000    8.16e+05    8.16e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.12   Jarque-Bera (JB):                32.10
# Prob(Q):                              0.73   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.92   Skew:                            -0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.76
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.77e+28. Standard errors may be unstable.
# Mean Squared Error (MSE): 2568836.02
# Mean Absolute Error (MAE): 1325.89
# Mean Absolute Percentage Error (MAPE): 6.55%
# Root Mean Squared Error (RMSE): 1602.76
# Relative RMSE (RRMSE): 0.1795
# Normalized RMSE (NRMSE): 0.0794
# R-squared (R²): 0.2901
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Assuming your model is called `arima_model`
forecast = arima_model.forecast(steps=7)  # 7 days forecast
forecast.index = pd.date_range(start='2021-09-12', periods=7, freq='D')
print(forecast)
# Out:
# 2021-09-12    18244.780849
# 2021-09-13    19414.104306
# 2021-09-14    20406.755281
# 2021-09-15    20717.740675
# 2021-09-16    20514.247754
# 2021-09-17    19903.905194
# 2021-09-18    19524.769092
# Freq: D, Name: predicted_mean, dtype: float64

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(6,1,6))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(6, 1, 6)   Log Likelihood               -1714.649
# Date:                Sun, 27 Jul 2025   AIC                           3455.298
# Time:                        21:38:21   BIC                           3499.297
# Sample:                    01-04-2021   HQIC                          3473.070
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1433      0.144      7.924      0.000       0.861       1.426
# ar.L2         -0.0756      0.152     -0.498      0.619      -0.373       0.222
# ar.L3         -0.4536      0.132     -3.433      0.001      -0.713      -0.195
# ar.L4         -0.4442      0.156     -2.852      0.004      -0.749      -0.139
# ar.L5          1.1851      0.139      8.533      0.000       0.913       1.457
# ar.L6         -0.4456      0.143     -3.121      0.002      -0.725      -0.166
# ma.L1         -1.3783      0.144     -9.585      0.000      -1.660      -1.096
# ma.L2          0.2831      0.192      1.475      0.140      -0.093       0.659
# ma.L3          0.4428      0.108      4.091      0.000       0.231       0.655
# ma.L4          0.4349      0.207      2.105      0.035       0.030       0.840
# ma.L5         -1.4080      0.194     -7.248      0.000      -1.789      -1.027
# ma.L6          0.7877      0.117      6.722      0.000       0.558       1.017
# sigma2      4.967e+05   5.64e+04      8.810      0.000    3.86e+05    6.07e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                33.49
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.42   Skew:                             0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 3451941.18
# Mean Absolute Error (MAE): 1537.18
# Mean Absolute Percentage Error (MAPE): 7.55%
# Root Mean Squared Error (RMSE): 1857.94
# Relative RMSE (RRMSE): 0.2081
# Normalized RMSE (NRMSE): 0.0920
# R-squared (R²): 0.0460
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(5,1,5))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(5, 1, 5)   Log Likelihood               -1714.656
# Date:                Sun, 27 Jul 2025   AIC                           3451.311
# Time:                        21:41:15   BIC                           3488.541
# Sample:                    01-04-2021   HQIC                          3466.349
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.6916      0.860      1.967      0.049       0.006       3.377
# ar.L2         -0.6034      2.338     -0.258      0.796      -5.185       3.978
# ar.L3         -1.1794      2.884     -0.409      0.683      -6.831       4.472
# ar.L4          1.4903      1.839      0.810      0.418      -2.114       5.094
# ar.L5         -0.4394      0.470     -0.935      0.350      -1.360       0.482
# ma.L1         -1.9142      0.843     -2.270      0.023      -3.567      -0.261
# ma.L2          0.9272      2.472      0.375      0.708      -3.918       5.773
# ma.L3          1.1207      3.272      0.343      0.732      -5.293       7.534
# ma.L4         -1.7917      2.288     -0.783      0.434      -6.276       2.693
# ma.L5          0.7368      0.692      1.065      0.287      -0.619       2.093
# sigma2        4.5e+05   4.18e+04     10.770      0.000    3.68e+05    5.32e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.39   Jarque-Bera (JB):                31.52
# Prob(Q):                              0.53   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.61   Skew:                             0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# Mean Squared Error (MSE): 3653469.62
# Mean Absolute Error (MAE): 1564.49
# Mean Absolute Percentage Error (MAPE): 7.86%
# Root Mean Squared Error (RMSE): 1911.41
# Relative RMSE (RRMSE): 0.2140
# Normalized RMSE (NRMSE): 0.0947
# R-squared (R²): -0.0097
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(3,1,6))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(3, 1, 6)   Log Likelihood               -1718.425
# Date:                Sun, 27 Jul 2025   AIC                           3456.850
# Time:                        21:44:59   BIC                           3490.695
# Sample:                    01-04-2021   HQIC                          3470.520
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.1412      0.068     31.707      0.000       2.009       2.274
# ar.L2         -2.1148      0.083    -25.401      0.000      -2.278      -1.952
# ar.L3          0.8963      0.065     13.817      0.000       0.769       1.023
# ma.L1         -2.4157      0.113    -21.302      0.000      -2.638      -2.193
# ma.L2          2.6459      0.270      9.809      0.000       2.117       3.175
# ma.L3         -1.3893      0.322     -4.312      0.000      -2.021      -0.758
# ma.L4          0.2223      0.270      0.822      0.411      -0.308       0.752
# ma.L5         -0.0650      0.186     -0.349      0.727      -0.429       0.300
# ma.L6          0.1051      0.078      1.348      0.178      -0.048       0.258
# sigma2      5.001e+05   2.02e-06   2.47e+11      0.000       5e+05       5e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                46.38
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.58   Skew:                             0.43
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.51e+27. Standard errors may be unstable.
# Mean Squared Error (MSE): 3712254.96
# Mean Absolute Error (MAE): 1608.16
# Mean Absolute Percentage Error (MAPE): 7.83%
# Root Mean Squared Error (RMSE): 1926.72
# Relative RMSE (RRMSE): 0.2158
# Normalized RMSE (NRMSE): 0.0954
# R-squared (R²): -0.0259
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(2,3,8))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(2, 3, 8)   Log Likelihood               -1726.672
# Date:                Sun, 27 Jul 2025   AIC                           3475.345
# Time:                        21:48:09   BIC                           3512.473
# Sample:                    01-04-2021   HQIC                          3490.345
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.5217      0.056    -27.179      0.000      -1.631      -1.412
# ar.L2         -0.9187      0.058    -15.797      0.000      -1.033      -0.805
# ma.L1         -0.5632      0.140     -4.012      0.000      -0.838      -0.288
# ma.L2         -1.1866      0.132     -8.974      0.000      -1.446      -0.927
# ma.L3         -0.2736      0.230     -1.190      0.234      -0.724       0.177
# ma.L4          1.1306      0.209      5.415      0.000       0.721       1.540
# ma.L5          0.0923      0.168      0.549      0.583      -0.237       0.422
# ma.L6          0.0267      0.130      0.204      0.838      -0.229       0.282
# ma.L7         -0.0673      0.111     -0.608      0.543      -0.284       0.150
# ma.L8         -0.1567      0.097     -1.623      0.105      -0.346       0.033
# sigma2      6.349e+05   9.31e+04      6.823      0.000    4.53e+05    8.17e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                38.38
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.93   Skew:                            -0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.95e+14. Standard errors may be unstable.
# Mean Squared Error (MSE): 3924280.95
# Mean Absolute Error (MAE): 1542.03
# Mean Absolute Percentage Error (MAPE): 7.58%
# Root Mean Squared Error (RMSE): 1980.98
# Relative RMSE (RRMSE): 0.2218
# Normalized RMSE (NRMSE): 0.0981
# R-squared (R²): -0.0845
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# === Step 1: Load and preprocess data ===
# Convert 'Date' column to datetime
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)

# Filter dataset between Jan 4, 2021, and Sep 18, 2021
data_filtered = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

# Keep original Date column separately
dates = data_filtered['Date']

# Normalize all columns except Date
scaler = MinMaxScaler()
features = data_filtered.drop(columns=['Date'])
normalized_features = pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
normalized_features['Date'] = dates

# === Step 2: Split into train/val/test ===
train_set = normalized_features[(normalized_features['Date'] >= '2021-01-04') & (normalized_features['Date'] <= '2021-07-02')]
val_set = normalized_features[(normalized_features['Date'] >= '2021-07-03') & (normalized_features['Date'] <= '2021-08-10')]
test_set = normalized_features[(normalized_features['Date'] >= '2021-08-11') & (normalized_features['Date'] <= '2021-09-18')]

# Reset index for each
train_set = train_set.reset_index(drop=True)
val_set = val_set.reset_index(drop=True)
test_set = test_set.reset_index(drop=True)

# === Step 3: Time series model on actual cases ===
# We'll use unnormalized actual cases for ARIMA forecasting
covid_cases_ts = data_filtered.set_index('Date')['New COVID-19 Cases']  # Replace 'Cases' with your actual column name

# Train ARIMA model on training + validation set
arima_train_series = covid_cases_ts['2021-01-04':'2021-08-10']
arima_model = ARIMA(arima_train_series, order=(0,3,7))  # You can optimize (p,d,q) or use auto_arima
arima_model = arima_model.fit()

# Print the model summary
print(arima_model.summary())

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np
import pandas as pd

# Step 4: Forecast and evaluate
test_data = covid_cases_ts['2021-08-11':'2021-09-18']
forecast = arima_model.forecast(steps=len(test_data))
forecast = pd.Series(forecast, index=test_data.index)

# Metrics
mse = mean_squared_error(test_data, forecast)
mae = mean_absolute_error(test_data, forecast)
mape = np.mean(np.abs((test_data - forecast) / test_data)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(test_data) - np.min(test_data))
nrmse = rmse / np.mean(test_data)  # Normalized RMSE by mean
r2 = r2_score(test_data, forecast)

# Print results
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:     New COVID-19 Cases   No. Observations:                  219
# Model:                 ARIMA(0, 3, 7)   Log Likelihood               -1724.559
# Date:                Sun, 27 Jul 2025   AIC                           3465.118
# Time:                        21:51:42   BIC                           3492.120
# Sample:                    01-04-2021   HQIC                          3476.027
#                          - 08-10-2021
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -2.1056      0.092    -22.946      0.000      -2.285      -1.926
# ma.L2          1.1641      0.162      7.199      0.000       0.847       1.481
# ma.L3         -0.0834      0.139     -0.602      0.547      -0.355       0.188
# ma.L4          0.0667      0.155      0.430      0.667      -0.237       0.371
# ma.L5         -0.0166      0.182     -0.092      0.927      -0.372       0.339
# ma.L6          0.0844      0.135      0.623      0.533      -0.181       0.350
# ma.L7         -0.1095      0.048     -2.290      0.022      -0.203      -0.016
# sigma2      4.806e+05    5.6e-07   8.58e+11      0.000    4.81e+05    4.81e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.03   Jarque-Bera (JB):                47.33
# Prob(Q):                              0.86   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.23   Skew:                            -0.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.43e+27. Standard errors may be unstable.
# Mean Squared Error (MSE): 4073554.02
# Mean Absolute Error (MAE): 1587.09
# Mean Absolute Percentage Error (MAPE): 7.68%
# Root Mean Squared Error (RMSE): 2018.30
# Relative RMSE (RRMSE): 0.2260
# Normalized RMSE (NRMSE): 0.0999
# R-squared (R²): -0.1258

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# === Load and preprocess data ===
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

target_col = 'New COVID-19 Cases'
target_series = data[[target_col, 'Date']].copy()

# === Define date-based splits (same as ARIMA) ===
train_data = target_series[(target_series['Date'] <= '2021-08-10')]
test_data = target_series[(target_series['Date'] >= '2021-08-11') & (target_series['Date'] <= '2021-09-18')]

# === Normalize based on training only ===
scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_data[[target_col]])
test_scaled = scaler.transform(test_data[[target_col]])

# === Create sequences ===
def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len:i])
        y.append(data[i])
    return np.array(X), np.array(y)

seq_length = 10
x_train, y_train = create_sequences(train_scaled, seq_length)
x_test, y_test = create_sequences(test_scaled, seq_length)

# === Build and train LSTM model ===
model = Sequential()
model.add(LSTM(64, input_shape=(seq_length, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')

model.fit(x_train, y_train, epochs=200, batch_size=16, verbose=1)

# === Predict on test set ===
y_pred = model.predict(x_test)

# === Inverse scale predictions and true values ===
y_pred_rescaled = scaler.inverse_transform(y_pred)
y_test_rescaled = scaler.inverse_transform(y_test)

# === Evaluate LSTM model ===
mse = mean_squared_error(y_test_rescaled, y_pred_rescaled)
mae = mean_absolute_error(y_test_rescaled, y_pred_rescaled)
mape = np.mean(np.abs((y_test_rescaled - y_pred_rescaled) / y_test_rescaled)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(y_test_rescaled) - np.min(y_test_rescaled))
nrmse = rmse / np.mean(y_test_rescaled)
r2 = r2_score(y_test_rescaled, y_pred_rescaled)

print("\n📊 Final LSTM Forecast Evaluation:")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")
# Out:
# Epoch 1/200
# E:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0982
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0124
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0035
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0026
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0026
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0027
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0030
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0032
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0025
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0027
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0023
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0033
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0033
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0025
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0023
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0026
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0031
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0029
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0022
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0024
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0026
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0023
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0023
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0024
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0019
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0026
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0041
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0023
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0021
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0021
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0020
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0022
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0023
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0029
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0026
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0022
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0026
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0028
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0030
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0019
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0021
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0020
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0019
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0021
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0018
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0022
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0018
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 109/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 110/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 111/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 112/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0019
# Epoch 113/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017
# Epoch 114/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 115/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 116/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0020
# Epoch 117/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0021
# Epoch 118/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0017
# Epoch 119/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 120/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015
# Epoch 121/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 122/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 123/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 124/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015
# Epoch 125/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014
# Epoch 126/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 127/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 128/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0017
# Epoch 129/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0017
# Epoch 130/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 131/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 132/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 133/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 134/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 135/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 136/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 137/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 138/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 139/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 140/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 141/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 142/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 143/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 144/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0016
# Epoch 145/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 146/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017
# Epoch 147/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Epoch 148/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 149/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 150/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018
# Epoch 151/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 152/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0021
# Epoch 153/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0020
# Epoch 154/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 155/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014
# Epoch 156/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 157/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016
# Epoch 158/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0017
# Epoch 159/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 160/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 161/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 162/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016
# Epoch 163/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 164/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 165/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0020
# Epoch 166/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 167/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0014
# Epoch 168/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0016
# Epoch 169/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0012
# Epoch 170/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015
# Epoch 171/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0010
# Epoch 172/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 173/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 174/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0013
# Epoch 175/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 176/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016
# Epoch 177/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0014
# Epoch 178/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 179/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0018
# Epoch 180/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 181/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 182/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014
# Epoch 183/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 184/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015
# Epoch 185/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0015
# Epoch 186/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013
# Epoch 187/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 188/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013
# Epoch 189/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0015
# Epoch 190/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0016
# Epoch 191/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0012
# Epoch 192/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014
# Epoch 193/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0012
# Epoch 194/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0014
# Epoch 195/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0012
# Epoch 196/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0014
# Epoch 197/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018
# Epoch 198/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014
# Epoch 199/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0013
# Epoch 200/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
#
# 📊 Final LSTM Forecast Evaluation:
# Mean Squared Error (MSE): 3140169.93
# Mean Absolute Error (MAE): 1521.03
# Mean Absolute Percentage Error (MAPE): 7.96%
# Root Mean Squared Error (RMSE): 1772.05
# Relative RMSE (RRMSE): 0.1984
# Normalized RMSE (NRMSE): 0.0889
# R-squared (R²): 0.2548

# %%
# === Define forecast horizon (same as your ARIMA example) ===
forecast_horizon = pd.date_range(start='2021-09-12', end='2021-09-18')

# === Start with the last known sequence from test data ===
last_sequence = test_scaled[-seq_length:]  # shape (10, 1)

forecast_scaled = []

for _ in range(len(forecast_horizon)):
    # Reshape to (1, seq_len, 1) for LSTM input
    input_seq = last_sequence.reshape((1, seq_length, 1))

    # Predict next value
    next_scaled = model.predict(input_seq, verbose=0)[0][0]

    # Append prediction
    forecast_scaled.append([next_scaled])

    # Update sequence: drop first, append prediction
    last_sequence = np.vstack((last_sequence[1:], [[next_scaled]]))

# Inverse transform forecasted values
forecast_scaled = np.array(forecast_scaled)
forecast_rescaled = scaler.inverse_transform(forecast_scaled)

# Convert to Pandas Series with date index
lstm_forecast_series = pd.Series(forecast_rescaled.flatten(), index=forecast_horizon)

print("\n📈 LSTM Rolling Forecast:")
print(lstm_forecast_series)
# Out:
# 📈 LSTM Rolling Forecast:
# 2021-09-12    18271.988281
# 2021-09-13    18724.783203
# 2021-09-14    18967.937500
# 2021-09-15    19182.982422
# 2021-09-16    19411.130859
# 2021-09-17    19678.951172
# 2021-09-18    19894.712891
# Freq: D, dtype: float32

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# === Step 1: Load and prepare data ===
data = pd.read_excel("C:\\Users\\A B Siddik\\Desktop\\ARIMA\\data.xlsx")
data['Date'] = pd.to_datetime(data['Date'], dayfirst=True)
data = data[(data['Date'] >= '2021-01-04') & (data['Date'] <= '2021-09-18')].reset_index(drop=True)

target_col = 'New COVID-19 Cases'
ts = data.set_index('Date')[target_col]

# === Step 2: Train/test split ===
train_ts = ts[:'2021-08-10']
test_ts = ts['2021-08-11':'2021-09-18']

# === Step 3: Fit best ARIMA model ===
best_order = (7, 4, 6)  # Use your best found (p,d,q) here
arima_model = ARIMA(train_ts, order=best_order).fit()

# === Step 4: Forecast on test set using ARIMA ===
arima_forecast = arima_model.forecast(steps=len(test_ts))
arima_forecast.index = test_ts.index

# === Step 5: Calculate residuals on training data ===
arima_pred_train = arima_model.predict(start=train_ts.index[1], end=train_ts.index[-1])
residuals = train_ts[1:] - arima_pred_train

# === Step 6: Scale residuals and create LSTM sequences ===
scaler = MinMaxScaler()
residuals_scaled = scaler.fit_transform(residuals.values.reshape(-1, 1))

def create_sequences(data, seq_len):
    X, y = [], []
    for i in range(seq_len, len(data)):
        X.append(data[i - seq_len:i])
        y.append(data[i])
    return np.array(X), np.array(y)

seq_len = 10
x_lstm, y_lstm = create_sequences(residuals_scaled, seq_len)

# === Step 7: Build and train LSTM ===
model = Sequential()
model.add(LSTM(64, input_shape=(seq_len, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_lstm, y_lstm, epochs=200, batch_size=16, verbose=1)

# === Step 8: Predict residuals on test set ===
resid_history = residuals_scaled[-seq_len:].flatten().tolist()
lstm_pred_scaled = []

for _ in range(len(test_ts)):
    input_seq = np.array(resid_history[-seq_len:]).reshape(1, seq_len, 1)
    pred = model.predict(input_seq, verbose=0)[0][0]
    lstm_pred_scaled.append(pred)
    resid_history.append(pred)

lstm_pred_resid = scaler.inverse_transform(np.array(lstm_pred_scaled).reshape(-1, 1)).flatten()

# === Step 9: Final hybrid forecast ===
hybrid_forecast = arima_forecast.values + lstm_pred_resid

# === Step 10: Evaluate hybrid model ===
actual = test_ts.values
mse = mean_squared_error(actual, hybrid_forecast)
mae = mean_absolute_error(actual, hybrid_forecast)
mape = np.mean(np.abs((actual - hybrid_forecast) / actual)) * 100
rmse = np.sqrt(mse)
rrmse = rmse / (np.max(actual) - np.min(actual))
nrmse = rmse / np.mean(actual)
r2 = r2_score(actual, hybrid_forecast)

print("\n📊 Final Hybrid ARIMA + LSTM Forecast Evaluation:")
print(f"ARIMA Order Used: {best_order}")
print(f"Mean Squared Error (MSE): {mse:.2f}")
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Relative RMSE (RRMSE): {rrmse:.4f}")
print(f"Normalized RMSE (NRMSE): {nrmse:.4f}")
print(f"R-squared (R²): {r2:.4f}")

# === Plot actual vs hybrid forecast ===
plt.figure(figsize=(10, 5))
plt.plot(test_ts.index, actual, label='Actual', marker='o')
plt.plot(test_ts.index, hybrid_forecast, label='Hybrid Forecast', marker='x')
plt.title(f"Hybrid ARIMA + LSTM Forecast\nR² = {r2:.4f}")
plt.xlabel("Date")
plt.ylabel("COVID-19 Cases")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# E:\anaconda\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Epoch 1/200
# E:\anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# E:\anaconda\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3349
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0306
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0213
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0150
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0175
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0186
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0161
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0169
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0205
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0137
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0189
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0168
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0164
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0184
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0169
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0132
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0170
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0166
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0161
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0172
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0170
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0181
# Epoch 33/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0148
# Epoch 34/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137
# Epoch 35/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176
# Epoch 36/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167
# Epoch 37/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0170
# Epoch 38/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0154
# Epoch 39/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# Epoch 40/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166
# Epoch 41/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0151
# Epoch 42/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174
# Epoch 43/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0149
# Epoch 44/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0177
# Epoch 45/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0184
# Epoch 46/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0180
# Epoch 47/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0170
# Epoch 48/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0173
# Epoch 49/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0172
# Epoch 50/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146
# Epoch 51/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0148
# Epoch 52/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0143
# Epoch 53/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0162
# Epoch 54/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0140
# Epoch 55/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 56/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0164
# Epoch 57/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0176
# Epoch 58/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 59/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0155
# Epoch 60/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182
# Epoch 61/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0147
# Epoch 62/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0157
# Epoch 63/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165
# Epoch 64/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 65/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 66/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0175
# Epoch 67/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126
# Epoch 68/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0187
# Epoch 69/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0175
# Epoch 70/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150
# Epoch 71/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141
# Epoch 72/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0169
# Epoch 73/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0168
# Epoch 74/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0155
# Epoch 75/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0157
# Epoch 76/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 77/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0171
# Epoch 78/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 79/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0166
# Epoch 80/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165
# Epoch 81/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179
# Epoch 82/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0207
# Epoch 83/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0156
# Epoch 84/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0143
# Epoch 85/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0140
# Epoch 86/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0148
# Epoch 87/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0154
# Epoch 88/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0154
# Epoch 89/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0160
# Epoch 90/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165
# Epoch 91/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0173
# Epoch 92/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0129
# Epoch 93/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0124
# Epoch 94/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0147
# Epoch 95/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0201
# Epoch 96/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0157
# Epoch 97/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0132
# Epoch 98/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134
# Epoch 99/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 100/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174
# Epoch 101/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 102/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0173
# Epoch 103/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0175
# Epoch 104/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0162
# Epoch 105/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0130
# Epoch 106/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0121
# Epoch 107/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0169
# Epoch 108/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0141
# Epoch 109/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0164
# Epoch 110/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0161
# Epoch 111/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0174
# Epoch 112/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147
# Epoch 113/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0151
# Epoch 114/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0160
# Epoch 115/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0160
# Epoch 116/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0148
# Epoch 117/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0177
# Epoch 118/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138
# Epoch 119/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187
# Epoch 120/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0145
# Epoch 121/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0162
# Epoch 122/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0165
# Epoch 123/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0180
# Epoch 124/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169
# Epoch 125/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0147
# Epoch 126/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0158
# Epoch 127/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0174
# Epoch 128/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0135
# Epoch 129/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0167
# Epoch 130/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# Epoch 131/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0186
# Epoch 132/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0163
# Epoch 133/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 134/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0161
# Epoch 135/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0154
# Epoch 136/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 137/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0156
# Epoch 138/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 139/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 140/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165
# Epoch 141/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 142/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0145
# Epoch 143/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0150
# Epoch 144/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162
# Epoch 145/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0162
# Epoch 146/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0159
# Epoch 147/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0181
# Epoch 148/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0139
# Epoch 149/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0149
# Epoch 150/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130
# Epoch 151/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191
# Epoch 152/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0157
# Epoch 153/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146
# Epoch 154/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0146
# Epoch 155/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0170
# Epoch 156/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0190
# Epoch 157/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0157
# Epoch 158/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0148
# Epoch 159/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0168
# Epoch 160/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0142
# Epoch 161/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0168
# Epoch 162/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0172
# Epoch 163/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0171
# Epoch 164/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0128
# Epoch 165/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0151
# Epoch 166/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0160
# Epoch 167/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146
# Epoch 168/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0160
# Epoch 169/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167
# Epoch 170/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0170
# Epoch 171/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 172/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0166
# Epoch 173/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0134
# Epoch 174/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0134
# Epoch 175/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0161
# Epoch 176/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0130
# Epoch 177/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0154
# Epoch 178/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0163
# Epoch 179/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 180/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0182
# Epoch 181/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0167
# Epoch 182/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0170
# Epoch 183/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 184/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0186
# Epoch 185/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0112
# Epoch 186/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0133
# Epoch 187/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0178
# Epoch 188/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0126
# Epoch 189/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0184
# Epoch 190/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0163
# Epoch 191/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0165
# Epoch 192/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0179
# Epoch 193/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0153
# Epoch 194/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0146
# Epoch 195/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0141
# Epoch 196/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0169
# Epoch 197/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0173
# Epoch 198/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0141
# Epoch 199/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0133
# Epoch 200/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0152
#
# 📊 Final Hybrid ARIMA + LSTM Forecast Evaluation:
# ARIMA Order Used: (7, 4, 6)
# Mean Squared Error (MSE): 2790887.69
# Mean Absolute Error (MAE): 1409.38
# Mean Absolute Percentage Error (MAPE): 6.92%
# Root Mean Squared Error (RMSE): 1670.60
# Relative RMSE (RRMSE): 0.1871
# Normalized RMSE (NRMSE): 0.0827
# R-squared (R²): 0.2287

# %%
# === Extract hybrid forecast for 12/9/21 to 18/9/21 ===
forecast_range = pd.date_range(start='2021-09-12', end='2021-09-18')
hybrid_forecast_series = pd.Series(hybrid_forecast, index=test_ts.index)
selected_forecast = hybrid_forecast_series.loc[forecast_range]

# Print forecasted values for the selected range
print("\n📅 Hybrid Forecast: 12/09/2021 to 18/09/2021")
print(selected_forecast.round(0).astype(int))
# Out:
# 📅 Hybrid Forecast: 12/09/2021 to 18/09/2021
# 2021-09-12    18480
# 2021-09-13    18269
# 2021-09-14    17997
# 2021-09-15    17736
# 2021-09-16    17433
# 2021-09-17    17153
# 2021-09-18    16839
# dtype: int32

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Dates
dates = pd.date_range(start='2021-09-12', end='2021-09-18')

# Actual values
actual = [19550, 19198, 16073, 15669, 19495, 18815, 17577]

# Forecast values
hybrid = [18480, 18269, 17997, 17736, 17433, 17153, 16839]
lstm = [18271.99, 18724.78, 18967.94, 19182.98, 19411.13, 19678.95, 19894.71]
arima = [18244.78, 19414.10, 20406.76, 20717.74, 20514.25, 19903.91, 19524.77]

# Create DataFrame
df = pd.DataFrame({
    'Actual': actual,
    'ARIMA': arima,
    'LSTM': lstm,
    'Hybrid': hybrid
}, index=dates)

 #Plotting
plt.figure(figsize=(14, 8))  # Bigger figure size

plt.plot(dates, actual, marker='o', label='Actual', color='black', linewidth=2)
plt.plot(dates, arima, marker='s', label='ARIMA Forecast', color='blue', linestyle='--')
plt.plot(dates, lstm, marker='^', label='LSTM Forecast', color='red', linestyle='--')
plt.plot(dates, hybrid, marker='D', label='Hybrid Forecast', color='green', linestyle='--')

# Labels and title with larger fonts
plt.xlabel('Date', fontsize=16)
plt.ylabel('Number of Active Cases', fontsize=16)
plt.title('Active cases: Actual vs ARIMA, LSTM, Hybrid (12–18 Sep 2021)', fontsize=18)

# Ticks font size
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

# Legend with larger font
plt.legend(fontsize=14)

# Grid and layout
plt.grid(True, linestyle='--', alpha=0.9)
plt.tight_layout()

# Show the plot
plt.show()

# %%
pip install dm-test
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement dm-test (from versions: none)
# ERROR: No matching distribution found for dm-test

# %%
import numpy as np
from scipy import stats

# Step 1: Actual and forecast values
actual = np.array([592, 292, 413, 463, 422, 346, 388])
arima = np.array([214.86, 217.82, 220.88, 224.04, 227.30, 230.65, 234.11])
lstm = np.array([675.27, 622.35, 533.94, 499.13, 658.87, 756.98, 876.39])
hybrid = np.array([367, 372, 378, 385, 391, 397, 404])

# Step 2: Calculate forecast errors
e_arima = actual - arima
e_lstm = actual - lstm
e_hybrid = actual - hybrid

# Step 3: Compute loss differentials (using squared error loss)
d_arima_lstm = (e_arima**2) - (e_lstm**2)
d_arima_hybrid = (e_arima**2) - (e_hybrid**2)

# Step 4: DM test statistic function
def dm_test(d, h=1):
    d_bar = np.mean(d)
    d_var = np.var(d, ddof=1)
    dm_stat = d_bar / np.sqrt((d_var / len(d)))
    p_value = 2 * (1 - stats.t.cdf(np.abs(dm_stat), df=len(d) - 1))
    return dm_stat, p_value

# Step 5: Run DM test between models
dm_stat_1, p_val_1 = dm_test(d_arima_lstm)
dm_stat_2, p_val_2 = dm_test(d_arima_hybrid)

# Step 6: Print results
print("DM Test: ARIMA vs. LSTM")
print(f"DM Statistic = {dm_stat_1:.4f}, p-value = {p_val_1:.4f}\n")

print("DM Test: ARIMA vs. Hybrid")
print(f"DM Statistic = {dm_stat_2:.4f}, p-value = {p_val_2:.4f}")
# Out:
# DM Test: ARIMA vs. LSTM
# DM Statistic = -0.8501, p-value = 0.4279
#
# DM Test: ARIMA vs. Hybrid
# DM Statistic = 3.1088, p-value = 0.0209
